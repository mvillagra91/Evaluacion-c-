-- %% [markdown]
-- # [Productos]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Productos]    Script Date: 09/01/2025 13:41:05 ******/
CREATE DATABASE [Productos]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Productos', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Productos.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Productos_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Productos_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Productos] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Productos].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Productos] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Productos] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Productos] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Productos] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Productos] SET ARITHABORT OFF 
GO
ALTER DATABASE [Productos] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Productos] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Productos] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Productos] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Productos] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Productos] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Productos] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Productos] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Productos] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Productos] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Productos] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Productos] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Productos] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Productos] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Productos] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Productos] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Productos] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Productos] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Productos] SET  MULTI_USER 
GO
ALTER DATABASE [Productos] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Productos] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Productos] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Productos] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Productos] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Productos] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Productos] SET QUERY_STORE = ON
GO
ALTER DATABASE [Productos] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[producto]

-- %%
USE [Productos]
GO

-- %%
/****** Object:  Table [dbo].[producto]    Script Date: 09/01/2025 13:41:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[producto](
	[id_product] [int] IDENTITY(1,1) NOT NULL,
	[name] [varchar](20) NULL,
	[description] [varchar](100) NULL,
	[category] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_product] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %%
SET IDENTITY_INSERT [dbo].[producto] ON 
INSERT [dbo].[producto] ([id_product], [name], [description], [category]) VALUES (1, N'DATO', N'PRUEBA', N'PRUEBA')
INSERT [dbo].[producto] ([id_product], [name], [description], [category]) VALUES (2, N'DATO', N'PRUEBA', N'PRUEBA')
INSERT [dbo].[producto] ([id_product], [name], [description], [category]) VALUES (3, N'DATO', N'PRUEBA', N'PRUEBA')
INSERT [dbo].[producto] ([id_product], [name], [description], [category]) VALUES (4, N'Producto A', N'Descripción del producto A', N'Categoría 1')
INSERT [dbo].[producto] ([id_product], [name], [description], [category]) VALUES (5, N'Producto A', N'Descripción del producto A', N'Categoría 1')
INSERT [dbo].[producto] ([id_product], [name], [description], [category]) VALUES (14, N'Producto X', N'Descripción X', N'Categoría X')
INSERT [dbo].[producto] ([id_product], [name], [description], [category]) VALUES (101, N'Producto X', N'Descripción X', N'Categoría X')
INSERT [dbo].[producto] ([id_product], [name], [description], [category]) VALUES (106, N'Producto X', N'Descripción X', N'Categoría X')
INSERT [dbo].[producto] ([id_product], [name], [description], [category]) VALUES (108, N'Producto Z', N'Descripción X', N'Categoría X')
SET IDENTITY_INSERT [dbo].[producto] OFF
GO

-- %% [markdown]
-- # [dbo].[actualizar_producto]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizar_producto]    Script Date: 09/01/2025 13:41:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimiento para actualizar un producto
CREATE PROCEDURE [dbo].[actualizar_producto](
    @id INT, 
    @nombre VARCHAR(20), 
    @descripcion VARCHAR(100), 
    @categoria VARCHAR(20)
)
AS
BEGIN
    BEGIN TRY
        UPDATE producto 
        SET name = @nombre, 
            description = @descripcion, 
            category = @categoria
        WHERE id_product = @id;
    END TRY
    BEGIN CATCH
        PRINT 'Error al actualizar el producto.';
    END CATCH
END;
GO

-- %% [markdown]
-- # [dbo].[producto_eliminar]

-- %%
/****** Object:  StoredProcedure [dbo].[producto_eliminar]    Script Date: 09/01/2025 13:41:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimiento para eliminar un producto (corregido el tipo de dato)
CREATE PROCEDURE [dbo].[producto_eliminar](
    @identificador_producto INT
)
AS
BEGIN
    BEGIN TRY
        DELETE FROM producto 
        WHERE id_product = @identificador_producto;
    END TRY
    BEGIN CATCH
        PRINT 'Error al eliminar el producto.';
    END CATCH
END;

GO

-- %% [markdown]
-- # [dbo].[producto_listar]

-- %%
/****** Object:  StoredProcedure [dbo].[producto_listar]    Script Date: 09/01/2025 13:41:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Procedimiento para listar todos los productos
CREATE PROCEDURE [dbo].[producto_listar]
AS
BEGIN
    -- Selecciona todos los productos, ordenados por el ID del producto
    SELECT * 
    FROM producto
    ORDER BY id_product ASC; -- Puedes cambiar el orden si lo deseas
END;

GO

-- %% [markdown]
-- # [dbo].[registrar_producto]

-- %%
/****** Object:  StoredProcedure [dbo].[registrar_producto]    Script Date: 09/01/2025 13:41:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[registrar_producto](
    @id INT,
    @nombre VARCHAR(20), 
    @descripcion VARCHAR(100), 
    @categoria VARCHAR(20)
)
AS
BEGIN
    BEGIN TRY
        -- Habilitar IDENTITY_INSERT solo si es necesario
        SET IDENTITY_INSERT [dbo].producto ON;

        INSERT INTO [dbo].[producto] ([id_product], [name], [description], [category])
        VALUES (@id, @nombre, @descripcion, @categoria);

        -- Deshabilitar IDENTITY_INSERT una vez usado
        SET IDENTITY_INSERT [dbo].producto OFF;
        
        PRINT 'Producto registrado exitosamente.';
    END TRY
    BEGIN CATCH
        -- Deshabilitar IDENTITY_INSERT en caso de error y mostrar el error
        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;

        IF OBJECTPROPERTY(OBJECT_ID('[dbo].producto'), 'TableHasIdentity') = 1
            SET IDENTITY_INSERT [dbo].producto OFF;

        PRINT 'Error al registrar el producto: ' + ERROR_MESSAGE();
    END CATCH
END;
GO

-- %% [markdown]
-- # [Productos]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Productos] SET  READ_WRITE 
GO
